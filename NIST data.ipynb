# %%
import pandas as pd
import numpy as np
import StringIO
# %matplotlib notebook
from matplotlib import pyplot as plt
from glob import glob

# %%
glob('NIST/*')
# Out:
# ['NIST/74-82-8-Mass.jdx',
#  'NIST/7732-18-5-Mass.jdx',
#  'NIST/630-08-0-Mass.jdx',
#  'NIST/7782-44-7-Mass.jdx']

# %%
pd.read_csv('NIST/74-82-8-Mass.jdx', comment='#',header=2, names=['col1'],sep='\s+, ,' , delimiter=',')
# Out:
#                               col1
# 12 380 13  1069 14 2042 15  8879.0
# 16 9999 17 164     NaN         NaN

# %%
# filename = 'NIST/74-82-8-Mass.jdx'
filename = 'NIST/7732-18-5-Mass.jdx'

A = np.array([])
with open(filename) as f:
    counter=0
    for x in f:
        counter=counter+1
        if (counter>9) & (x[0] !=("#" or "C"or "o")):
            xp = x.replace(b' ',b',') 
#             print xp
            A=np.append(A,np.loadtxt( StringIO.StringIO(xp), delimiter=','))
m= A[0::2]  
r= A[1::2]

# %%
plt.bar(m,r/1e4)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
r[4]/r[2]
# Out:
# 0.003000300030003

# %%
r[2]
# Out:
# 9999.0
